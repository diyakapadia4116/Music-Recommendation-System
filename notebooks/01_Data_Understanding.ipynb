# %% [markdown]
# # Music Recommendation System
#
# ## Data Understanding
#
# In this notebook, I explore the raw Spotify dataset to understand its structure, features, and quality before performing any data cleaning or analysis.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/spotify_tracks.csv")
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %% [markdown]
# The dataset contains information about Spotify tracks, including song details, artist information, popularity, and audio features.

# %%
df.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %% [markdown]
# | Column       | Description                           |
# | ------------ | ------------------------------------- |
# | track_name   | Name of the song                      |
# | artists      | Artist(s)                             |
# | album_name   | Album title                           |
# | popularity   | Popularity score (0–100)              |
# | danceability | How suitable the track is for dancing |
# | energy       | Intensity and activity level          |
# | valence      | Musical positivity                    |
# | tempo        | Speed of the song (BPM)               |

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  str
#  2   artists           113999 non-null  str
#  3   album_name        113999 non-null  str
#  4   track_name        113999 non-null  str
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %% [markdown]
# Most audio features are stored as floating-point numbers, while song names and artist names are stored as text.

# %%
df.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
#checking missing values
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#checking duplicates 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking unique values

df["artists"].nunique()
# Out:
# 31437

# %%
df["track_name"].nunique()
# Out:
# 73608

# %%
df["track_genre"].nunique()
# Out:
# 114

# %%
df.sample(10)
# Out:
#        Unnamed: 0                track_id  \
# 3121         3121  5oJgIQPvytf2nR7WX3vZLn
# 67494       67494  0N8d25eR5OMLON40UYIukg
# 6382         6382  2sx2JMObNBuPIrhRp2VfHR
# 24200       24200  65EjTv04s8iJB5vBcOolqF
# 35063       35063  3LPUvP4DGq3j0SqBdKWFiN
# 14439       14439  7sdA0lcpUh8F2EWWevWZD0
# 53266       53266  2MEH84HKs9zYHcA82mVzBy
# 30697       30697  2AwTFpFcTm9TyOXqu2OZ8D
# 69436       69436  4uDT6Y5C2WrEFbgla3JmYO
# 48842       48842  3Lf5fr3itZilalJH51cJVZ
#
#                                                  artists  \
# 3121                                              Weezer
# 67494                                             Juanes
# 6382                                            Månegarm
# 24200                                       Seth Troxler
# 35063                        Zé Vaqueiro;Vitor Fernandes
# 14439                                        The Wiggles
# 53266                                    Zedd;Liam Payne
# ...

# %% [markdown]
# ## Summary
#
# The dataset contains Spotify tracks with rich audio features such as danceability, energy, tempo, loudness, and valence.
#
# The dataset appears suitable for building a content-based music recommendation system.
#
# Some duplicate records and missing values were identified, which will be addressed in the next notebook during the data cleaning stage.
